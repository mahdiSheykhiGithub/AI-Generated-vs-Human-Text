# %% [markdown]
# <a href="https://colab.research.google.com/github/mahdiSheykhiGithub/AI-Generated-vs-Human-Text/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries and Load Data

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
import pickle

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AI Vs Human Text/AI_Human.csv')
data
# Out:
#                                                      text  generated
# 0       Cars. Cars have been around since they became ...        0.0
# 1       Transportation is a large necessity in most co...        0.0
# 2       "America's love affair with it's vehicles seem...        0.0
# 3       How often do you ride in a car? Do you drive a...        0.0
# 4       Cars are a wonderful thing. They are perhaps o...        0.0
# ...                                                   ...        ...
# 487230  Tie Face on Mars is really just a big misunder...        0.0
# 487231  The whole purpose of democracy is to create a ...        0.0
# 487232  I firmly believe that governments worldwide sh...        1.0
# 487233  I DFN't agree with this decision because a LFT...        0.0
# 487234  Richard Non, Jimmy Carter, and Bob Dole and ot...        0.0
#
# [487235 rows x 2 columns]

# %%
data.shape
# Out:
# (487235, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487235 entries, 0 to 487234
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   text       487235 non-null  object
#  1   generated  487235 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 7.4+ MB

# %% [markdown]
# # Text Preprocessing

# %%
def text_preprocess(text):
    punc = list(string.punctuation)
    bad = stopwords.words('english')
    bad_tokens = punc + bad
    tokens = word_tokenize(text)
    lemma = WordNetLemmatizer()
    word_tokens = [t for t in tokens if t.isalpha()]
    clean_tokens = [lemma.lemmatize(t.lower()) for t in word_tokens if t not in bad_tokens]
    return " ".join(clean_tokens)

# %%
data['clean_text'] = data['text'].apply(text_preprocess)
data.head()
# Out:
#                                                 text  generated  \
# 0  Cars. Cars have been around since they became ...        0.0
# 1  Transportation is a large necessity in most co...        0.0
# 2  "America's love affair with it's vehicles seem...        0.0
# 3  How often do you ride in a car? Do you drive a...        0.0
# 4  Cars are a wonderful thing. They are perhaps o...        0.0
#
#                                           clean_text
# 0  car car around since became famous henry ford ...
# 1  transportation large necessity country worldwi...
# 2  america love affair vehicle seems cooling say ...
# 3  how often ride car do drive one motor vehicle ...
# 4  car wonderful thing they perhaps one world gre...

# %%
with open('/content/drive/MyDrive/Colab Notebooks/AI Vs Human Text/clear_data.pickle', 'wb') as f:
    pickle.dump(data,f)
